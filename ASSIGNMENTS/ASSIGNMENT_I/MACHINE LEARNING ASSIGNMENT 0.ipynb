# %% [markdown]
# # MACHINE LEARNING ASSIGNMENT 0

# %% [markdown]
# # Name: Gaurav Mahadik

# %% [markdown]
# # INDEX

# %% [markdown]
# I.   Introduction
#
# II.  Review
#
# III. Data
#
# IV.  Conclusion
#
# V.   References

# %% [markdown]
# # I.  INTROUDCTION

# %% [markdown]
# The aim of this assignment is to study about Data Visualization using Jupyter Notebook. The Programming language used is Python and its libraries such as Numpy,Pandas,Matplotlib etc have been used. In this assignment I have used two datasets namely The Black Friday Dataset and The Diamonds Dataset to understand the patterns in the data and visualize them in this assignment.
#
# Data Visualization is to analyse patterns, trends and correlation that might not be recognised in text-based format are described in a visual context for better overall understanding.Scatter plot, histogram, bar graph, matrix diagram, tableau are good visualization tools.
#
# Classification predictive modeling is the task of approximating a mapping function (f) from input variables (X) to discrete output variables (y).The output variables are often called labels or categories. The mapping function predicts the class or category for a given observation.The probabilities can be interpreted as the likelihood or confidence of a given example belonging to each class. A predicted probability can be converted into a class value by selecting the class label that has the highest probability.
#
# Regression predictive modeling is the task of approximating a mapping function (f) from input variables (X) to a continuous output variable (y). A continuous output variable is a real-value, such as an integer or floating point value. These are often quantities, such as amounts and sizes. Because a regression predictive model predicts a quantity, the skill of the model must be reported as an error in those predictions.There are many ways to estimate the skill of a regression predictive model,but perhaps the most common is to calculate the root mean squared error,abbreviated by the acronym RMSE.

# %% [markdown]
# #  II. REVIEW

# %% [markdown]
# # Linear Algebra Review

# %% [markdown]
# Linear algebra is an essential branch of mathematics that is very important and is widely used throughout science and engineering. The study of Algebra includes several types of mathematical objects as follows:
#
# Scalar - A scalar is just a single number, in contrast to most of the other objects studied in linear algebra, which are usually arrays of multiple numbers.
#
# Vectors: A vector is an array of numbers. The numbers are arranged in order. We can identify each individual number by its index in that ordering.
#
# Matrix: is a 2-D array of numbers, so each element is identified by two indices instead of just one. We usually give matrices uppercase variable names with bold typeface, such as A.
#
# Tensor: an array of numbers arranged on a regular grid with a variable number of axes is known as a tensor.
#
# Transpose of a Matrix:  is the mirror image of the matrix across a diagonal line, called the main diagonal, running down and to the right, starting from its upper left corner.
#
# Matrix Multiplication: The product of matrices A and B is a third matrix C. In order for this product to be defined, A must have the same number of columns as B has rows. If A is of shape m × n and B is of shape n × p, then C is of shape m × p.
#
# Linear algebra offers a powerful tool called matrix inversion that enables us to analytically solve equation
#
# Identity Matrix: An identity matrix is a matrix that does not change any vector when we multiply that vector by that matrix.
#
# Inverse of a Matrix: The matrix obtained by multiplying original matrix with an identity matrix is called inverse of a Matrix. It is very useful for solving equations in Linear Algebra.
#
# Types of Matrices:
#
# Diagonal Matrix:  consist mostly of zeros and have nonzero entries only along the main diagonal.
#
# Orthogonal matrix: is a square matrix whose rows are mutually orthonormal and whose columns are mutually orthonormal:
#
# Eigen Decomposition: one of the most widely used kinds of matrix decomposition is called Eigen decomposition, in which we decompose a matrix into a set of eigenvectors and Eigen values.
#
# Determinant: the determinant of a square matrix, denoted det(A), is a function that maps matrices to real scalars. The determinant is equal to the product of all the Eigen values of the matrix.

# %% [markdown]
# # Probablity and Information Theory Review

# %% [markdown]
# Probability theory is a branch of mathematics that deals with quantities having random distributions. It provides a means of quantifying uncertainty as well as axioms for deriving new uncertain statements.
#
# Information Theory helps us to quantify the amount of uncertainty in a probability distribution.
#
# There are three possible sources of uncertainty:
#
# Inherent stochasticity in the system being modeled.
# Incomplete observability
# Incomplete modeling.
#
#
# Types of Probability:
#
# Frequentist probability: Frequentist probability is directly related to the rate at which events occur.
# Bayesian Probability: Bayesian Probability related to qualitative levels of certainty
#
# Marginal Probability:  the marginal distribution of a subset of a collection of random variables is the probability distribution of the variables contained in the subset. It gives the probabilities of various values of the variables in the subset without reference to the values of the other variables.
#
# Conditional Probability:  conditional probability is a measure of the conditional probability is a measure of the probability of an event another event has occurred. If the event of interest is A and the event B is known or assumed to have occurred, "the conditional probability of A given B", or "the probability of A under the condition B", is usually written as P(A|B), or sometimes PB(A) or P(A/B).
#
# Probability Distribution: a function of a discrete variable whose integral over any interval is the probability that the random variable specified by it will lie within that interval.
#
# Probability Mass Function: is a function that gives the probability that a discrete random variable is exactly equal to some value. The probability mass function is often the primary means of defining a discrete probability distribution, and such functions exist for either scalar or multivariate random variables whose domain is discrete.
#
# The most commonly used Probabilistic Distribution in Machine Learning are Bernoulli distribution, Multinoullid, Gaussian distribution, Exponential & Laplace distributions and Empirical distribution.
#
# Expectation: The expected value (or mean) of X, where X is a discrete random variable, is a weighted average of the possible values that X can take, each value being weighted according to the probability of that event occurring. The expected value of X is usually written as E(X) or m.
#
# Variance: The variance is the square of the standard deviation, the second central moment of a distribution, and the covariance of the random variable with itself
#
# Standard Deviation: Standard deviation is a widely used measurement of variability or diversity used in statistics and probability theory.

# %% [markdown]
# # III. DATA

# %% [markdown]
# # Regression Data

# %% [markdown]
# # 1.1 Introduction of Data for Regression

# %% [markdown]
# The data set which has been used is a Black Friday Sales Dataset having 537577 rows and 14 columns. It is the dataset which has data of the customers with attributes like their gender,age, city category, no od years they have been staying in that city and their marital status.Also we have the data of the products that were on sale on the Black Friday with details such as the product_id, different categories of the product and the cost at which those products were sold to which customer.

# %% [markdown]
# # 1.2 Source of the Data

# %% [markdown]
# https://www.kaggle.com/mehdidag/black-friday

# %% [markdown]
# # 2. Reading the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("BlackFriday.csv")

# %%
df1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %% [markdown]
# The data has been read from the csv file using read_csv method from Pandas library to display the dataset here in the jupyter notebook.

# %% [markdown]
# # 3. Preprocessing the Data

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
# User_ID                       537577 non-null int64
# Product_ID                    537577 non-null object
# Gender                        537577 non-null object
# Age                           537577 non-null object
# Occupation                    537577 non-null int64
# City_Category                 537577 non-null object
# Stay_In_Current_City_Years    537577 non-null object
# Marital_Status                537577 non-null int64
# Product_Category_1            537577 non-null int64
# Product_Category_2            370591 non-null float64
# Product_Category_3            164278 non-null float64
# Purchase                      537577 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 49.2+ MB

# %%
df1.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df1.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# ...

# %% [markdown]
# Checking which columns have null values

# %%
df1.isna().any()
# Out:
# User_ID                       False
# Product_ID                    False
# Gender                        False
# Age                           False
# Occupation                    False
# City_Category                 False
# Stay_In_Current_City_Years    False
# Marital_Status                False
# Product_Category_1            False
# Product_Category_2             True
# Product_Category_3             True
# Purchase                      False
# dtype: bool

# %% [markdown]
# Product_Category_2 and Product_Category_3 have null values. As the values in these columns are numeric we can store 0
# in place of those value as there is no recorded data for the same.

# %%
df1.Product_Category_2.fillna(0,inplace = True)
df1.Product_Category_3.fillna(0,inplace = True)

# %%
df1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %% [markdown]
# Rechecking that there are no null values now

# %%
df1.isna().any()
# Out:
# User_ID                       False
# Product_ID                    False
# Gender                        False
# Age                           False
# Occupation                    False
# City_Category                 False
# Stay_In_Current_City_Years    False
# Marital_Status                False
# Product_Category_1            False
# Product_Category_2            False
# Product_Category_3            False
# Purchase                      False
# dtype: bool

# %%
df1.corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023024        0.018732            0.003687
# Occupation         -0.023024    1.000000        0.024691           -0.008114
# Marital_Status      0.018732    0.024691        1.000000            0.020546
# Product_Category_1  0.003687   -0.008114        0.020546            1.000000
# Product_Category_2  0.003663    0.006792        0.001146           -0.040730
# Product_Category_3  0.003938    0.011941       -0.004363           -0.389048
# Purchase            0.005389    0.021104        0.000129           -0.314125
#
#                     Product_Category_2  Product_Category_3  Purchase
# User_ID                       0.003663            0.003938  0.005389
# Occupation                    0.006792            0.011941  0.021104
# Marital_Status                0.001146           -0.004363  0.000129
# Product_Category_1           -0.040730           -0.389048 -0.314125
# ...

# %% [markdown]
# # 4. Visualization of the data

# %% [markdown]
# Male-Female Ratio plot

# %%
groupName = []                                    #making different groups of genders to be plotted ahead
count = []
for group_name, subset in df1.groupby('Gender'):
    groupName.append(group_name)
    count.append(len(subset))
print(groupName)
print(count)
# Out:
# ['F', 'M']
# [132197, 405380]

# %%
plt.figure(figsize = (7, 7))
plt.pie(count, labels = groupName)
plt.show()

# %% [markdown]
# As per the above pie chart we can state that the number of men shopping on black friday is almost three times the number of women.

# %% [markdown]
# Age-Gender Plot

# %%
fig = plt.subplots(figsize=(10,10))
sns.countplot(df1['Age'],hue=df1['Gender'])

# %% [markdown]
# In the above bar graph we can see that there are a lot of males in the age group of 26-35 compared
# to the women who did shopping on Black Friday. Also we can see the tha males in the age group 36-45
# and 18-25 which buy more products as compared to women on thisparticular black friday as per the
# data we have in this dataset.

# %% [markdown]
# Occupation Count Plot

# %%
sns.countplot(df1.Occupation)
plt.title("Occupation Count Plot", color = 'green', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Occupation Count Plot')

# %% [markdown]
# The people with occupation number 4 are the highest followed by occupation number 0 and occupation number 7  followed by other occupations as we can see in the above Occupation count plot

# %% [markdown]
# Occupation-Gender Plot

# %%
m = df1[df1.Gender == 'M']['Occupation'].value_counts(sort=False)
w = df1[df1.Gender == 'F']['Occupation'].value_counts(sort=False)
pd.DataFrame({'M': m, 'F': w}, index=range(0,21)).plot.bar(stacked=True)
plt.gcf().set_size_inches(15, 10)
plt.title("Diferent Occupations performed by the two genders", size=18)
plt.legend(loc="upper left")
plt.xlabel('Occupation', size=20)
plt.ylabel('Count', size=20)
plt.show()

# %% [markdown]
# Heat Map

# %%
f = plt.subplots(figsize=(10, 10))
sns.heatmap(df1.corr(), annot=True, linewidths=.1,fmt= '.1f')
plt.show()

# %% [markdown]
# There is negative correlation between Product_Category_1 and Product_Category_3 which tells us that as the number of sales of Product_Category_1 increases the number of sales of Product_Category_3 decreases which means that onces the customer purchases products of Product_Category_1 then that customer will not take a product from Product_Category_3.Product_Category_1 has a negative correlation with Purchase.
#
# Product_Category_3 has a strong correlation with Purchase.This might be possible if the products from Product_Category_3 are cheap. We can check the mean of all categories to verify.

# %%
cat_1 = df1['Product_Category_1'].mean()
cat_2 = df1['Product_Category_2'].mean()
cat_3= df1['Product_Category_3'].mean()
print(f"PC1: {cat_1}  PC2: {cat_2} PC3 : {cat_3}")
# Out:
# PC1: 5.295546498455105  PC2: 6.784907092379324 PC3 : 3.871772787898292

# %% [markdown]
# Hence the strong correlation can be explained by the above calculation. As the products of Product_Category_3 are cheap therefore there is high correlation between Product_Category_3 and Purchase.

# %% [markdown]
# # Preliminary Observation

# %% [markdown]
# As we have seen above after each visualization that this dataset is giving us a lot of insight about the details of the products
# that have been purchased by various customers and the trends in the variety of the customer purchasing these products.

# %% [markdown]
# The dataset tells us that the people having occupation number 0, 4 and 7 have shopped significantly more compared to the
# people having any other occupation. People with occupation number 4 being the highest followed by occupation number 0
# followed by occupation nnumber 7 followed by the remaining ones.

# %% [markdown]
# The pie chart tells us that the number of males shopping is almost three times the number of women on this particular black firday.

# %% [markdown]
# The bar graphs show us that precisely males in the age group of 26-35 have done more  shopping compared to the women in the
# same age group and actually more than anyone else in the whole dataset. It is followed by the males in the age group of 36-45
# followed by the males in the age group 18-25.

# %% [markdown]
# The heatmap shows us that the cutsomers are not purchasing any products from Product_Category_3 after purchasing products from Product_Category_1. Also as we calculated above products of Product_Category_3 are cheap so there is strong correlation between Product_Category_3 and Purchase.

# %% [markdown]
# # CLASSIFICATION DATA

# %% [markdown]
# # 1.1 Introduction of Data for Regression

# %% [markdown]
# This classic dataset contains the prices and other attributes of almost 54,000 diamonds along with 10 feature variables which are as follows:
# 1.price- Price of the Diamonds(USD)
#
# 2.carat- Carat Weight of the Diamonds
#
# 3.cut -  Quality of the cut that is Fair, Good, Very Good, Premium, Ideal
#
# 4.color- Color of the diamonds from J (worst) to D (best)
#
# 5.clarity- Clarity is a measurement of how clear the diamond is. Its from I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best)
#
# 6.x - Length of the Diamonds in mm
#
# 7.y - Width  of the Diamondsin mm
#
# 8.z  - Depth  of the Diamondsin mm
#
# 9.depth - Total depth percentage  2 * z / (x + y)
#
# 10.table - Width of top of diamond relative to widest point

# %% [markdown]
# # 1.2 Source of the Data

# %% [markdown]
# https://www.kaggle.com/shivam2503/diamonds

# %% [markdown]
# # 2. Reading the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2 =  pd.read_csv('diamonds.csv')

# %%
df2
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %% [markdown]
# # 3.  Preprocessing the Data

# %%
df2['volume'] = df2['x']*df2['y']*df2['z']
data = df2[df2['volume']<1000]

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z', 'volume'],
#       dtype='object')

# %%
df2.columns = ['Index','carat', 'cut', 'color', 'clarity', 'depth', 'table',
       'price', 'x', 'y', 'z','volume']

# %%
df2.head()
# Out:
#    Index  carat      cut color clarity  depth  table  price     x     y     z  \
# 0      1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1      2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2      3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3      4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4      5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#       volume
# 0  38.202030
# 1  34.505856
# 2  38.076885
# 3  46.724580
# 4  51.917250

# %%
df2 = df2.iloc[:,1:]

# %%
df2
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9       0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# ...

# %%
df2['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df2.corr()
# Out:
#            carat     depth     table     price         x         y         z  \
# carat   1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth   0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table   0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price   0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x       0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y       0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z       0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000
# volume  0.976308  0.009157  0.167400  0.902385  0.956564  0.975143  0.950065
#
#           volume
# carat   0.976308
# depth   0.009157
# table   0.167400
# price   0.902385
# x       0.956564
# y       0.975143
# z       0.950065
# volume  1.000000

# %% [markdown]
# # 4. Visualization

# %% [markdown]
# Price-Carat Plot

# %%
sns.set(style="white", color_codes=True)
g = sns.jointplot(y="price", x="carat", data=df2)

# %% [markdown]
# The Diamond Carat weight is varying exponentially with the Price of the diamond. Therefore higher the carat weight costlier is the diamond.

# %% [markdown]
# Graphs showing the frequency of the Clarity and Cut of the Diamonds.

# %%
f, axes = plt.subplots(1, 2,figsize=(12,8))
sns.countplot(x= "cut", data=df2,  orient='h' , ax=axes[0])
sns.countplot(x= "clarity", data=df2,  orient='h' , ax=axes[1])

# %% [markdown]
# In the above graph we can see that there is a high frequency of diamonds having Ideal cut followed by Premium Cut followed by Very Good Cut.
#
# Also we can observe that among the diamonds that we have in this dataset there is high number of diamonds having SI1 clarity followed by VS2 clarity.

# %% [markdown]
# Graphs showing the frequency of the Depth and Color of the Diamonds.

# %%
f, axes = plt.subplots(1, 2,figsize=(12,8))
sns.countplot(x= "depth", data=df2,  orient='v' , ax=axes[0])
sns.countplot(x= "color", data=df2,  orient='v' , ax=axes[1])

# %% [markdown]
# From the above graphs it can be seen that the diamond with color G has the highest frequency followed by the diamond with color E followed by the others.

# %% [markdown]
# Box Plot of the Cut and Price of the Diamonds.

# %%
sns.boxplot(x='cut', y='price', data=df2)

# %% [markdown]
# Premium Diamond Cut is the most expensive followed by very good cut.

# %% [markdown]
# Volume-Price Plot

# %%
sns.set(style="white", color_codes=True)
g = sns.jointplot(x="volume", y="price", data=df2)

# %% [markdown]
# There is a kind of Linear Relationship between the Price and volume. As the volume is increasing the price of the diamonds is also increasing.

# %% [markdown]
# Heat Map

# %%
f = plt.subplots(figsize=(10, 10))
corr = df2.corr()
sns.heatmap(data=corr, square=True, annot=True,cbar=True)
plt.show()

# %% [markdown]
# From the heat map we can observe that there is a neagtive corelation between depth and Price which states that as the depth of the diamond reduces the price of the Diamond increases as there is negative correlation between them.
# It can be seen that there is a positive correltation between the price and the dimensions of the diamonds as well as with the volume of the Diamond.

# %% [markdown]
# # 5. Preliminary Observations

# %% [markdown]
# After the analysis of the Dataset from the above visualization the following observations can be seen as follows

# %% [markdown]
# The Diamond Carat Weight is varying exponentially with the Diamond price.

# %% [markdown]
# There is a high frequency of diamonds having Ideal cut followed by Premium Cut followed by Very Good Cut.

# %% [markdown]
# It can be seen that in this dataset there is high number of diamonds having SI1 clarity followed by VS2 clarity.

# %% [markdown]
# It can be seen that the diamond with color G has the highest frequency followed by the diamond with color E followed by the others.

# %% [markdown]
# It can be seen that Premium Diamond Cut is the most expensive followed by very good cut.

# %% [markdown]
# There is a Linear Relationship between the Price of the Diamonds and the volume of the Diamonds.

# %% [markdown]
# There is neagtive corelation between depth and Price of the Diamonds and there is a positive correltation between the price and the dimensions of the diamonds as well as with the volume of the Diamond.

# %% [markdown]
# # IV. CONCLUSION

# %% [markdown]
# In this assignment we have undertsood the use of tools like Numpy, Matplotlib, Seaborn, Plotly and Jupyter Notebook for visualizing the data from the two datasets that have been chosen for this particular assignment. In this assignment we were able to learn about data cleaning, data preprocessing and then visualizing the data in the form of graphs, plots and heatmaps.

# %% [markdown]
# # V. REFERENCES

# %% [markdown]
# 1. Black Friday Data. Retrieved from https://www.kaggle.com/mehdidag/black-friday.
# 2. Diamonds Data. Retrieved from https://www.kaggle.com/shivam2503/diamonds.
# 3. Matplotlib. Retrieved from https://matplotlib.org/.
# 4. Seaborn. Retrieved from https://seaborn.pydata.org/.
#
#      And more.
